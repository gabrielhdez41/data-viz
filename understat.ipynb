# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Leeds 2 - 2 Everton: 16390
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
#get only the shotsData
strings = scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22425633\\x22,\\x22minute\\x22\\x3A\\x221\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.8880000305175781\\x22,\\x22Y\\x22\\x3A\\x220.3110000038146973\\x22,\\x22xG\\x22\\x3A\\x220.054759711027145386\\x22,\\x22player\\x22\\x3A\\x22Scott\\x20McTominay\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225560\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216377\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Leeds\\x22,\\x22h_goals\\x22\\x3A\\x225\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222021\\x2D08\\x2D14\\x2011\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Bruno\\x20Fernandes\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22425634\\x22,\\x22minute\\x22\\x3A\\x225\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.7090000152587891\\x22,\\x22Y\\x22\\x3A\\x220.6\\x22,\\x22xG\\x22\\x3A\\x220.016773398965597153\\x22,\\x22player\\x22\\x3A\\x22Mason\\x20Greenwood\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227490\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2216377\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Leeds\\x22,\\x22h_goals\\x22\\x3A\\x225\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222021\\x2D08\\x2D14\\x2011\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Scott\\x20McTominay\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22425636\\x22,\\x22minute\\x22\\x3A\\x2210\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.88\\x22,\\x22Y\\x22\\x3A\\x220.44\\x22,\\x22xG\\x22\\x3A\\x220.024532323703169823\\x22,\\x22player\\x22\\x3A\\x22Harry\\x20Maguire\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x221687\\x22,\\x22situation\\x22\\x3A\\x22FromCorner\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22Head\\x22,\\x22match_id\\x22\\x3A\\x2216377\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Leeds\\x22,\\x22h_goals\\x22\\x3A\\x225\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222021\\x2D08\\x2D14\\x2011\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Luke\\x20Shaw\\x22,\\x22lastAction\\x22\\x3A\\x22Cross\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22425637\\x22,\\x22minute\\x22\\x3A\\x2211\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.8630000305175781\\x22,\\x22Y\\x22\\x3A\\x220.65\\x22,\\x22xG\\x22\\x3A\\x220.22996944189071655\\x22,\\x22player\\x22\\x3A\\x22Paul\\x20Pogba\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x221740\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2216377\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Leeds\\x22,\\x22h_goals\\x22\\x3A\\x225\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222021\\x2D08\\x2D14\\x2011\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Mason\\x20Greenwood\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22425638\\x22,\\x22minute\\x22\\x3A\\x2214\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.850999984741211\\x22,\\x22Y\\x22\\x3A\\x220.5520000076293945\\x22,\\x22xG\\x22\\x3A\\x220.02588074281811714\\x22,\\x22player\\x22\\x3A\\x22Daniel\\x20James\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225595\\x22,\\x22situation\\x22\\x3A\\x22FromCorner\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2216377\\x22,\\x22h_team\\x22\\x ...

# %%
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')

data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '425633',
#    'minute': '1',
#    'result': 'BlockedShot',
#    'X': '0.8880000305175781',
#    'Y': '0.3110000038146973',
#    'xG': '0.054759711027145386',
#    'player': 'Scott McTominay',
#    'h_a': 'h',
#    'player_id': '5560',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Pass'},
#   {'id': '425634',
#    'minute': '5',
#    'result': 'SavedShot',
#    'X': '0.7090000152587891',
#    'Y': '0.6',
#    'xG': '0.016773398965597153',
#    'player': 'Mason Greenwood',
#    'h_a': 'h',
#    'player_id': '7490',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Scott McTominay',
#    'lastAction': 'Pass'},
#   {'id': '425636',
#    'minute': '10',
#    'result': 'MissedShots',
#    'X': '0.88',
#    'Y': '0.44',
#    'xG': '0.024532323703169823',
#    'player': 'Harry Maguire',
#    'h_a': 'h',
#    'player_id': '1687',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Cross'},
#   {'id': '425637',
#    'minute': '11',
#    'result': 'MissedShots',
#    'X': '0.8630000305175781',
#    'Y': '0.65',
#    'xG': '0.22996944189071655',
#    'player': 'Paul Pogba',
#    'h_a': 'h',
#    'player_id': '1740',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Mason Greenwood',
#    'lastAction': 'Pass'},
#   {'id': '425638',
#    'minute': '14',
#    'result': 'BlockedShot',
#    'X': '0.850999984741211',
#    'Y': '0.5520000076293945',
#    'xG': '0.02588074281811714',
#    'player': 'Daniel James',
#    'h_a': 'h',
#    'player_id': '5595',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '425642',
#    'minute': '26',
#    'result': 'SavedShot',
#    'X': '0.7340000152587891',
#    'Y': '0.42400001525878905',
#    'xG': '0.019063765183091164',
#    'player': 'Paul Pogba',
#    'h_a': 'h',
#    'player_id': '1740',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Pass'},
#   {'id': '425643',
#    'minute': '29',
#    'result': 'Goal',
#    'X': '0.860999984741211',
#    'Y': '0.6170000076293946',
#    'xG': '0.3290913999080658',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Paul Pogba',
#    'lastAction': 'Throughball'},
#   {'id': '425644',
#    'minute': '32',
#    'result': 'MissedShots',
#    'X': '0.879000015258789',
#    'Y': '0.7440000152587891',
#    'xG': '0.043794721364974976',
#    'player': 'Luke Shaw',
#    'h_a': 'h',
#    'player_id': '1006',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Pass'},
#   {'id': '425646',
#    'minute': '35',
#    'result': 'MissedShots',
#    'X': '0.8919999694824219',
#    'Y': '0.36700000762939455',
#    'xG': '0.10489168763160706',
#    'player': 'Daniel James',
#    'h_a': 'h',
#    'player_id': '5595',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Pass'},
#   {'id': '425647',
#    'minute': '41',
#    'result': 'BlockedShot',
#    'X': '0.7219999694824218',
#    'Y': '0.5720000076293945',
#    'xG': '0.02128627523779869',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Daniel James',
#    'lastAction': 'Pass'},
#   {'id': '425648',
#    'minute': '44',
#    'result': 'SavedShot',
#    'X': '0.8519999694824218',
#    'Y': '0.5940000152587891',
#    'xG': '0.09427323937416077',
#    'player': 'Daniel James',
#    'h_a': 'h',
#    'player_id': '5595',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Paul Pogba',
#    'lastAction': 'Pass'},
#   {'id': '425650',
#    'minute': '51',
#    'result': 'Goal',
#    'X': '0.9469999694824218',
#    'Y': '0.68',
#    'xG': '0.08111144602298737',
#    'player': 'Mason Greenwood',
#    'h_a': 'h',
#    'player_id': '7490',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Paul Pogba',
#    'lastAction': 'Pass'},
#   {'id': '425651',
#    'minute': '53',
#    'result': 'Goal',
#    'X': '0.9059999847412109',
#    'Y': '0.3079999923706055',
#    'xG': '0.07142012566328049',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Paul Pogba',
#    'lastAction': 'Pass'},
#   {'id': '425652',
#    'minute': '59',
#    'result': 'Goal',
#    'X': '0.9019999694824219',
#    'Y': '0.35200000762939454',
#    'xG': '0.3619175851345062',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Victor Lindelöf',
#    'lastAction': 'Throughball'},
#   {'id': '425653',
#    'minute': '67',
#    'result': 'Goal',
#    'X': '0.9030000305175782',
#    'Y': '0.5309999847412109',
#    'xG': '0.1419793665409088',
#    'player': 'Fred',
#    'h_a': 'h',
#    'player_id': '6817',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Paul Pogba',
#    'lastAction': 'Pass'},
#   {'id': '425654',
#    'minute': '73',
#    'result': 'MissedShots',
#    'X': '0.7709999847412109',
#    'Y': '0.37400001525878906',
#    'xG': '0.021732861176133156',
#    'player': 'Mason Greenwood',
#    'h_a': 'h',
#    'player_id': '7490',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'}],
#  'a': [{'id': '425635',
#    'minute': '8',
#    'result': 'MissedShots',
#    'X': '0.81',
#    'Y': '0.48700000762939455',
#    'xG': '0.04164135828614235',
#    'player': 'Mateusz Klich',
#    'h_a': 'a',
#    'player_id': '4381',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Jack Harrison',
#    'lastAction': 'Pass'},
#   {'id': '425639',
#    'minute': '15',
#    'result': 'SavedShot',
#    'X': '0.7830000305175782',
#    'Y': '0.6569999694824219',
#    'xG': '0.01783052645623684',
#    'player': 'Jack Harrison',
#    'h_a': 'a',
#    'player_id': '8720',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '425640',
#    'minute': '15',
#    'result': 'SavedShot',
#    'X': '0.7559999847412109',
#    'Y': '0.605999984741211',
#    'xG': '0.016877274960279465',
#    'player': 'Mateusz Klich',
#    'h_a': 'a',
#    'player_id': '4381',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Jack Harrison',
#    'lastAction': 'TakeOn'},
#   {'id': '425641',
#    'minute': '25',
#    'result': 'MissedShots',
#    'X': '0.9109999847412109',
#    'Y': '0.545',
#    'xG': '0.10462424904108047',
#    'player': 'Patrick Bamford',
#    'h_a': 'a',
#    'player_id': '822',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Raphinha',
#    'lastAction': 'Cross'},
#   {'id': '425645',
#    'minute': '33',
#    'result': 'BlockedShot',
#    'X': '0.8269999694824218',
#    'Y': '0.34700000762939454',
#    'xG': '0.022880351170897484',
#    'player': 'Raphinha',
#    'h_a': 'a',
#    'player_id': '8026',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Patrick Bamford',
#    'lastAction': 'Chipped'},
#   {'id': '425649',
#    'minute': '48',
#    'result': 'Goal',
#    'X': '0.765',
#    'Y': '0.35',
#    'xG': '0.021045027300715446',
#    'player': 'Luke Ayling',
#    'h_a': 'a',
#    'player_id': '8716',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Stuart Dallas',
#    'lastAction': 'Pass'},
#   {'id': '425655',
#    'minute': '78',
#    'result': 'MissedShots',
#    'X': '0.745999984741211',
#    'Y': '0.6090000152587891',
#    'xG': '0.011944416910409927',
#    'player': 'Tyler Roberts',
#    'h_a': 'a',
#    'player_id': '1014',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '425656',
#    'minute': '79',
#    'result': 'MissedShots',
#    'X': '0.795',
#    'Y': '0.6769999694824219',
#    'xG': '0.018221013247966766',
#    'player': 'Hélder Costa',
#    'h_a': 'a',
#    'player_id': '3428',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Liam Cooper',
#    'lastAction': 'HeadPass'},
#   {'id': '425657',
#    'minute': '85',
#    'result': 'MissedShots',
#    'X': '0.875999984741211',
#    'Y': '0.625999984741211',
#    'xG': '0.28141355514526367',
#    'player': 'Raphinha',
#    'h_a': 'a',
#    'player_id': '8026',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': 'Tyler Roberts',
#    'lastAction': 'Pass'},
#   {'id': '425658',
#    'minute': '86',
#    'result': 'MissedShots',
#    'X': '0.850999984741211',
#    'Y': '0.4909999847412109',
#    'xG': '0.03186383843421936',
#    'player': 'Luke Ayling',
#    'h_a': 'a',
#    'player_id': '8716',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16377',
#    'h_team': 'Manchester United',
#    'a_team': 'Leeds',
#    'h_goals': '5',
#    'a_goals': '1',
#    'date': '2021-08-14 11:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'}]}

# %%
x = []
y = []
xG = []
result = []
team = []
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])

# %%
col_names = ['x','y','xG','result','team']
df = pd.DataFrame([x,y,xG,result,team],index=col_names)
df = df.T

# %%
df['x'] = df['x'].astype(float)*100
df['y'] = df['y'].astype(float)*100
df['xG'] = df['xG'].astype(float)
df
# Out:
#             x          y        xG       result               team
# 0   88.800003  31.100000  0.054760  BlockedShot  Manchester United
# 1   70.900002  60.000000  0.016773    SavedShot  Manchester United
# 2   88.000000  44.000000  0.024532  MissedShots  Manchester United
# 3   86.300003  65.000000  0.229969  MissedShots  Manchester United
# 4   85.099998  55.200001  0.025881  BlockedShot  Manchester United
# 5   73.400002  42.400002  0.019064    SavedShot  Manchester United
# 6   86.099998  61.700001  0.329091         Goal  Manchester United
# 7   87.900002  74.400002  0.043795  MissedShots  Manchester United
# 8   89.199997  36.700001  0.104892  MissedShots  Manchester United
# 9   72.199997  57.200001  0.021286  BlockedShot  Manchester United
# 10  85.199997  59.400002  0.094273    SavedShot  Manchester United
# 11  94.699997  68.000000  0.081111         Goal  Manchester United
# 12  90.599998  30.799999  0.071420         Goal  Manchester United
# 13  90.199997  35.200001  0.361918         Goal  Manchester United
# 14  90.300003  53.099998  0.141979         Goal  Manchester United
# 15  77.099998  37.400002  0.021733  MissedShots  Manchester United
# 16  81.000000  48.700001  0.041641  MissedShots              Leeds
# 17  78.300003  65.699997  0.017831    SavedShot              Leeds
# 18  75.599998  60.599998  0.016877    SavedShot              Leeds
# 19  91.099998  54.500000  0.104624  MissedShots              Leeds
# 20  82.699997  34.700001  0.022880  BlockedShot              Leeds
# 21  76.500000  35.000000  0.021045         Goal              Leeds
# 22  74.599998  60.900002  0.011944  MissedShots              Leeds
# 23  79.500000  67.699997  0.018221  MissedShots              Leeds
# 24  87.599998  62.599998  0.281414  MissedShots              Leeds
# 25  85.099998  49.099998  0.031864  MissedShots              Leeds
